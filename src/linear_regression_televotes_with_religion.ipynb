# %%
import pandas as pd
import statsmodels.api as sm
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Loading the dataset

# %%
file_path = "../data/fulldata.csv"
data = pd.read_csv(file_path, low_memory = False)

# %%
data.head()
# Out:
#    Unnamed: 0  year  round from_country to_country  total_points  tele_points  \
# 0           0  1960  final           at         fr             1          NaN
# 1           1  1960  final           at         gb             3          NaN
# 2           2  1960  final           at         mc             0          NaN
# 3           3  1960  final           at         no             1          NaN
# 4           4  1960  final           at         de             2          NaN
#
#    jury_points  Year_from iso-alpha-3_from  ...  city_to        lat_to  \
# 0          NaN       1960              AUT  ...    Paris  3.760847e+06
# 1          NaN       1960              AUT  ...   London  3.620981e+06
# 2          NaN       1960              AUT  ...   Monaco  4.111648e+06
# 3          NaN       1960              AUT  ...     Oslo  4.362948e+06
# 4          NaN       1960              AUT  ...   Berlin  4.551651e+06
#
#          lon_to  GDP per capita (current US$)_to  Population, total_to  \
# 0  2.889644e+06                 1302.53149729892              47412964
# 1  3.203213e+06                  1397.5948032844              52400000
# 2  2.295892e+06                               ..                 21808
# 3  4.091117e+06                  1451.2850779894               3581239
# 4  3.273670e+06                 1162.12266831735              72814900
#
#       distance jaccard_artists jaccard_genre  dice_genre  dice_artists
# 0  1036.040752        0.153846      0.090909    0.166667      0.266667
# 1  1237.492544        0.302326      0.224490    0.366667      0.464286
# 2   852.872041        0.111111      0.200000    0.333333      0.200000
# 3  1353.489212        0.292683      0.200000    0.333333      0.452830
# 4   524.812724        0.666667      0.666667    0.800000      0.800000
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Preprocessing the dataset

# %%
# IMPORTANT: No Australia, Serbia (because of religion dataset) and only Grand Final tele votes, so year >= 2016

data2 = data[(data["from_country"] != "au") & (data["to_country"] != "au") & (data["round"] == "final") & (data["from_country"] != "rs") & (data["to_country"] != "rs") & (data["year"] >= 2016)].copy()

columns_to_use = ["from_country", "to_country", "tele_points", "distance","GDP per capita (current US$)_from", "GDP per capita (current US$)_to", "dice_genre", "dice_artists",
                  "chrstcatpct_from","chrstcatpct_to", "chrstprotpct_from", "chrstprotpct_to", "islmgenpct_from", "islmgenpct_to", "judgenpct_from", "judgenpct_to"]
data2.replace("..",float("nan"),inplace=True)
filtered_data = data2[columns_to_use].dropna()

filtered_data["GDP per capita (current US$)_from"] = pd.to_numeric(filtered_data["GDP per capita (current US$)_from"], errors="coerce")
filtered_data["GDP per capita (current US$)_to"] = pd.to_numeric(filtered_data["GDP per capita (current US$)_to"], errors="coerce")
filtered_data["GDP_Difference"] = filtered_data["GDP per capita (current US$)_from"] - filtered_data["GDP per capita (current US$)_to"]

filtered_data["distance_normalized"] = (    # Normalize distance
    filtered_data["distance"] - filtered_data["distance"].mean()
) / filtered_data["distance"].std()

filtered_data["Catholism_Difference"] = filtered_data["chrstcatpct_from"] - filtered_data["chrstcatpct_to"]
filtered_data["Protestant_Difference"] = filtered_data["chrstprotpct_from"] - filtered_data["chrstprotpct_to"]
filtered_data["Islam_Difference"] = filtered_data["islmgenpct_from"] - filtered_data["islmgenpct_to"]
filtered_data["Judaism_Difference"] = filtered_data["judgenpct_from"] - filtered_data["judgenpct_to"]
filtered_data = filtered_data.dropna(subset=["Catholism_Difference", "Protestant_Difference", "Islam_Difference", "Judaism_Difference"])

columns_to_use = ["from_country", "to_country", "tele_points", "distance", "distance_normalized", "GDP_Difference", "dice_genre", "dice_artists", "Catholism_Difference", "Protestant_Difference", "Islam_Difference", "Judaism_Difference"]
filtered_data = filtered_data[columns_to_use]

aggregated_data = filtered_data.groupby(["from_country", "to_country"], as_index = False).agg({
    "tele_points": "mean",     # Average points awarded
    "distance": "mean",          # Distance
    "distance_normalized": "mean",
    "GDP_Difference": "mean",
    "dice_genre" : "mean",
    "dice_artists": "mean",
    "Catholism_Difference":"mean",
    "Protestant_Difference": "mean",
    "Islam_Difference": "mean",
    "Judaism_Difference": "mean"
})

aggregated_data["GDP_Difference"] = (     # Normalize GDP
    aggregated_data["GDP_Difference"] - aggregated_data["GDP_Difference"].mean()
) / aggregated_data["GDP_Difference"].std()


aggregated_data["Catholism_Difference"] = (aggregated_data["Catholism_Difference"] - aggregated_data["Catholism_Difference"].mean()) / aggregated_data[     # Normalize Religion
        "Catholism_Difference"
    ].std()
aggregated_data["Protestant_Difference"] = (aggregated_data["Protestant_Difference"] - aggregated_data["Protestant_Difference"].mean()) / aggregated_data[
    "Protestant_Difference"
].std()
aggregated_data["Islam_Difference"] = (aggregated_data["Islam_Difference"] - aggregated_data["Islam_Difference"].mean()) / aggregated_data[
    "Islam_Difference"
].std()
aggregated_data["Judaism_Difference"] = (aggregated_data["Judaism_Difference"] - aggregated_data["Judaism_Difference"].mean()) / aggregated_data[
    "Judaism_Difference"
].std()

aggregated_data
# Out:
#      from_country to_country  tele_points     distance  distance_normalized  \
# 0              al         am     0.500000  2073.730122             0.357418
# 1              al         at     0.500000   808.975149            -0.998184
# 2              al         az     0.600000  2507.648698             0.822505
# 3              al         be     1.000000  1589.695421            -0.161385
# 4              al         bg     7.250000   328.355601            -1.513326
# ...           ...        ...          ...          ...                  ...
# 1612           ua         ro     1.500000   749.666799            -1.061753
# 1613           ua         ru     8.000000   760.610235            -1.050023
# 1614           ua         se     2.166667  1269.957029            -0.504090
# 1615           ua         si     0.000000  1280.992967            -0.492261
# 1616           ua         sm     0.000000  1544.418564            -0.209914
#
#       GDP_Difference  dice_genre  dice_artists  Catholism_Difference  \
# 0           0.039631    1.000000      1.000000              0.287937
# 1          -1.291837    0.333333      0.200000             -1.009535
# 2           0.032429    1.000000      1.000000              0.287937
# 3          -1.241187    0.333333      0.266667             -0.979126
# 4          -0.103903    0.200000      0.313725              0.270705
# ...              ...         ...           ...                   ...
# 1612       -0.265650    0.200000      0.666667             -0.062583
# 1613       -0.187784    0.100000      0.260870              0.014251
# 1614       -1.510822    0.200000      0.200000             -0.010685
# 1615       -0.725373    0.200000      0.375000             -1.267611
# 1616       -1.445996    0.200000      0.217391             -1.654419
#
#       Protestant_Difference  Islam_Difference  Judaism_Difference
# 0                  0.011443          2.400311            0.004585
# 1                 -0.151492          2.217969           -0.000341
# 2                  0.010357         -1.268547            0.000275
# 3                 -0.015713          2.208311           -0.011424
# 4                 -0.003764          1.903507            0.003969
# ...                     ...               ...                 ...
# 1612              -0.104241         -0.009538            0.012589
# 1613               0.023120         -0.441055            0.006432
# 1614              -1.783560         -0.225876            0.002122
# 1615               0.035884         -0.109981            0.014436
# 1616               0.063039          0.005142            0.015052
#
# [1617 rows x 12 columns]

# %% [markdown]
# ## Overall Linear Regression for distance

# %% [markdown]
# First, we want to investigate whether the overall distance between the capitals of voting and receiving countries has a significant impact on the average points awarded in the Grand Final over the years.

# %%
X_agg = sm.add_constant(aggregated_data["distance_normalized"])
Y_agg = aggregated_data["tele_points"]

agg_model = sm.OLS(Y_agg, X_agg).fit()      # Ordinary Least Squares for Linear Regression
agg_summary = agg_model.summary()

distance_mean = aggregated_data["distance"].mean()      # Unnormalized distance predictions back to original scale for plotting
distance_std = aggregated_data["distance"].std()
x_plot_original = np.linspace(aggregated_data["distance"].min(), aggregated_data["distance"].max(), 100)        
x_plot_normalized = (x_plot_original - distance_mean) / distance_std
x_plot_with_const = sm.add_constant(x_plot_normalized)
y_plot = agg_model.predict(x_plot_with_const)

plt.figure(figsize=(8, 5))
plt.scatter(aggregated_data["distance_normalized"], aggregated_data["tele_points"], alpha=0.5, label="Average points by normalized distance")
plt.plot(aggregated_data["distance_normalized"], agg_model.predict(X_agg), color="red", label="Regression line")
plt.title("Linear Regression: Average tele Points vs. Normalized Distance")
plt.xlabel("Normalized distance between capitals")
plt.ylabel("Average total points")
plt.legend()
plt.grid(True)
plt.savefig("../plots/linear_regression/overall_normalized_tele.png")
plt.show()

plt.figure(figsize=(8, 5))
plt.scatter(aggregated_data["distance"], aggregated_data["tele_points"], alpha=0.5, label="Average points by distance")
plt.plot(x_plot_original, y_plot, color="red", label="Regression line")
plt.title("Linear Regression: Average tele Points vs. Distance")
plt.xlabel("Distance between capitals (km)")
plt.ylabel("Average total points")
plt.legend()
plt.grid(True)
plt.savefig("../plots/linear_regression/overall_tele.png")
plt.show()

print(agg_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            tele_points   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     80.99
# Date:                Tue, 28 Jan 2025   Prob (F-statistic):           6.20e-19
# Time:                        18:08:51   Log-Likelihood:                -3742.1
# No. Observations:                1617   AIC:                             7488.
# Df Residuals:                    1615   BIC:                             7499.
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   2.2074      0.061     36.224      0.000       2.088       2.327
# distance_normalized    -0.5533      0.061     -9.000      0.000      -0.674      -0.433
# ==============================================================================
# Omnibus:                      398.866   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              822.981
# Skew:                           1.428   Prob(JB):                    1.96e-179
# Kurtosis:                       5.015   Cond. No.                         1.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Results explanation

# %% [markdown]
# · R²: 0.048 → Only 4.8% of the variance in the average points awarded can be explained by the distance, so distance is not a strong predictor of the overall voting behavior.

# %% [markdown]
# · Prob (F-statistic): 6.20e-19 → The very low p-value (<0.05) indicates that the overall model is statistically significant, meaning that distance should have some effect on Eurovision voting, but very small.

# %% [markdown]
# · Coefficients:
#
# - Intercept (const): 2.2074 → Represents the predicted average points a country at an average distance from another country would receive.
#
# - Distance Coefficient (normalized): -0.5533 → For every 1-standard deviation increase in distance, the expected number of points decreases by that amount.
#
# - p-value (P>|t|): 0.000 → The effect of distance is highly statistically significant (unlikely to be due to random chance).

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Though statistically significant, this effect is very small in magnitude, suggesting that distance only slightly reduces the points awarded.
#
# While distance has a small but significant negative impact on points awarded, the low R² suggests that other factors (such as cultural, political, and historical ties) likely play a much larger role

# %% [markdown]
# ## Overall Linear Regression with multiple factor (distance, GDP, music preferences, religion)

# %% [markdown]
# Fist, we have to select and normalize the data we are going to use:

# %% [markdown]
# ### Regression with distance

# %%
X_full = aggregated_data[["distance_normalized", "GDP_Difference", "dice_genre", "dice_artists", "Catholism_Difference", "Protestant_Difference", "Islam_Difference", "Judaism_Difference"]]
X_full = sm.add_constant(X_full)
Y = aggregated_data["tele_points"]

model_full = sm.OLS(Y, X_full).fit()
print("Regression including distance:\n", model_full.summary())
# Out:
# Regression including distance:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:            tele_points   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     15.40
# Date:                Tue, 28 Jan 2025   Prob (F-statistic):           5.47e-22
# Time:                        18:08:52   Log-Likelihood:                -3721.9
# No. Observations:                1617   AIC:                             7462.
# Df Residuals:                    1608   BIC:                             7510.
# Df Model:                           8
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     1.8898      0.127     14.938      0.000       1.642       2.138
# distance_normalized      -0.5114      0.062     -8.286      0.000      -0.632      -0.390
# GDP_Difference            0.2124      0.090      2.360      0.018       0.036       0.389
# dice_genre               -1.1667      0.419     -2.783      0.005      -1.989      -0.344
# dice_artists              1.7556      0.433      4.050      0.000       0.905       2.606
# Catholism_Difference      0.0762      0.080      0.948      0.343      -0.081       0.234
# Protestant_Difference    -0.2790      0.095     -2.951      0.003      -0.464      -0.094
# Islam_Difference          0.1431      0.066      2.157      0.031       0.013       0.273
# Judaism_Difference       -0.0670      0.065     -1.035      0.301      -0.194       0.060
# ==============================================================================
# Omnibus:                      387.142   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              788.170
# Skew:                           1.392   Prob(JB):                    7.10e-172
# Kurtosis:                       4.986   Cond. No.                         12.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Results Explanation

# %% [markdown]
# · R²: 0.071 → Only 7.1% of the variance in the average points awarded can be explained by the independent variables, meaning that distance, GDP difference, and music similarity do not strongly predict voting behavior in Eurovision.

# %% [markdown]
# · Prob (F-statistic): 5.47e-22 → The very low p-value (<0.05) indicates that the overall model is statistically significant, meaning that at least one of the predictors has an effect on Eurovision voting, even if the explanatory power is weak.

# %% [markdown]
# · Coefficients:
#
# - Intercept (const): 1.8898 → Represents the predicted average points a country receives at an average distance, GDP difference, and music similarity.
#
# - Distance Coefficient: -0.5114 → For every 1-standard deviation increase in distance, the expected number of points decreases by that amount.
# - Distance p-value (P>|t|): 0.000 → The effect of distance is highly statistically significant (unlikely due to random chance).
#
# - GDP Difference Coefficient: 0.2124 → For every 1-standard deviation increase in distance, the expected number of points also increases by that amount.
# - GDP difference p-value (P>|t|): 0.018 → This variable is significant, meaning GDP difference may influence slightly in the Eurovision tele voting behavior.
#
# - Dice Genre Coefficient: -1.1667 → A higher similarity in music genres leads to less points being awarded.
# - Genres preference p-value (P>|t|): 0.005 → This variable is statistically significant, meaning genre similarity may impact Eurovision tele voting behavior.
#
# - Dice Artists Coefficient: 1.7556 → A higher similarity in music artists leads to more points being awarded.
# - Artists preference p-value (P>|t|): 0.000 → This effect is highly statistically significant, meaning countries with similar top artists impact Eurovision tele voting behavior.
#
# - Catholism Difference Coefficient: 0.0762 → A higher difference in the percentaje of catholic population leads to slightly more points being awarded.
# - Catholism Difference p-value (P>|t|): 0.343 → This effect is not statistically significant, meaning difference in the percentaje of catholic population does not impact Eurovision tele voting behavior.
#
# - Protestantism Difference Coefficient: -0.2790 → A higher difference in the percentaje of protestant population leads to slightly less points being awarded.
# - Protestantism Difference p-value (P>|t|): 0.003 → This effect is highly statistically significant, meaning difference in the percentaje of protestant population does impact Eurovision tele voting behavior.
#
# - Islamic Difference Coefficient: 0.1431 → A higher difference in the percentaje of islamic population leads to slightly more points being awarded.
# - Islamic Difference p-value (P>|t|): 0.031 → This effect is statistically significant, meaning difference in the percentaje of islamic population does impact Eurovision tele voting behavior.
#
# - Judaism Difference Coefficient: -0.0670 → A higher difference in the percentaje of jewish population leads to slightly more points being awarded.
# - Judaism Difference p-value (P>|t|): 0.301 → This effect is not statistically significant, meaning difference in the percentaje of jewish population does not impact Eurovision tele voting behavior.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# While distance has a moderate and statistically significant negative impact, its effect remains limited, as shown by the still low R² value.
#
# GDP difference has a small positive effect but is statistically insignificant, so it does not impact Eurovision voting behavior.
#
# Music taste matters more:
# - Genre similarity (dice_genre) is statiscally insignificant, suggesting that shared musical styles do not influence on voting patterns, though the effect is relatively small.
# - Artist similarity (dice_artists) is highly significant, meaning that countries with overlapping favorite artists tend to vote for each other.
#
# This suggests that Eurovision voting is influenced more by cultural and musical connections rather than economic factors or pure geographic distance.
#
# However, the low R² value indicates that many other factors (such as historical alliances, politics, language, and diaspora voting) likely play a much larger role.

# %% [markdown]
# ### Regression without distance

# %% [markdown]
# Now we are going to rerun the regression without distance to determine how much influence distance had on the model.
#
# If removing distance significantly changes the coefficients, p-values, or R², it would suggest that distance was a key predictor. If nothing changes much, then distance was not contributing significantly to explaining the variation in voting behavior.

# %%
X_no_distance = aggregated_data[["GDP_Difference", "dice_genre", "dice_artists", "Catholism_Difference", "Protestant_Difference", "Islam_Difference", "Judaism_Difference"]]
X_no_distance = sm.add_constant(X_no_distance)

model_no_distance = sm.OLS(Y, X_no_distance).fit()
print("\nRegression without distance:\n", model_no_distance.summary())
# Out:
# Regression without distance:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:            tele_points   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     7.480
# Date:                Tue, 28 Jan 2025   Prob (F-statistic):           6.97e-09
# Time:                        18:08:52   Log-Likelihood:                -3755.7
# No. Observations:                1617   AIC:                             7527.
# Df Residuals:                    1609   BIC:                             7571.
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     1.7848      0.128     13.890      0.000       1.533       2.037
# GDP_Difference            0.2131      0.092      2.319      0.021       0.033       0.393
# dice_genre               -1.5187      0.426     -3.567      0.000      -2.354      -0.684
# dice_artists              2.3509      0.436      5.388      0.000       1.495       3.207
# Catholism_Difference      0.0723      0.082      0.882      0.378      -0.088       0.233
# Protestant_Difference    -0.2795      0.096     -2.897      0.004      -0.469      -0.090
# Islam_Difference          0.1527      0.068      2.255      0.024       0.020       0.286
# Judaism_Difference       -0.0685      0.066     -1.037      0.300      -0.198       0.061
# ==============================================================================
# Omnibus:                      427.513   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              934.944
# Skew:                           1.495   Prob(JB):                    9.54e-204
# Kurtosis:                       5.221   Cond. No.                         12.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Results Comparison

# %% [markdown]
# · R² decreased: (from 0.060 to 0.016) → When distance was removed, the model's explanatory power dropped significantly. This indicates that distance had a notable effect on predicting voting behavior, but it is still weak.
#
# · GDP difference remains statistically insignificant (p=0.760 → p=807) → The economic gap between countries continues to have no meaningful influence on Eurovision voting, reinforcing that economic factors do not drive voting behavior.
#
# · Genre coefficient decreased: (from -0.7667 to -1.1748) and became Significant (p=0.064 → p=0.005) → In the absence of distance, genre similarity became more negatively impactful and statistically significant. This suggests that countries with similar music genres may vote less for each other, potentially due to preferences for diversity or differentiation in voting.
#
# · Artists coefficient increased: (from 1.4941 to 2.1815) → Artist similarity became even more influential when distance was removed, suggesting that distance and artist similarity were correlated. Countries close to each other not only vote for each other due to proximity but also because they share music artists.

# %% [markdown]
# ### Analysis of the residuals distribution plot

# %%
residuals_full = model_full.resid
residuals_no_distance = model_no_distance.resid

plt.figure(figsize=(8, 5))
sns.histplot(residuals_full, bins=30, color="blue", alpha=0.5, label="With Distance", kde=True)
sns.histplot(residuals_no_distance, bins=30, color="red", alpha=0.5, label="Without Distance", kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residual Distribution: With vs. Without Distance")
plt.legend()
plt.grid(True)
plt.savefig("../plots/linear_regression/residuals_tele.png")
plt.show()

# %% [markdown]
# · General shape and distribution:
#
# - The residuals show a right-skewed distribution, meaning the model underpredicts points more often than it overpredicts.
#
# - The majority of residuals are clustered between -2.5 and 2.5, with a peak slightly below -2, indicating that the model's predictions are generally close to actual values but slightly underestimated.
#
# - The long right tail suggests that there are cases where the model fails to capture extreme scores, possibly due to outliers such as politically or culturally aligned countries that award each other more points than expected.
#
# · Comparison: with vs. without distance:
#
# - The blue curve (with distance) and red curve (without distance) are almost identical, meaning that removing distance does not significantly alter the model's error distribution.
# - This reinforces the idea that distance is not a key explanatory variable in predicting Eurovision voting behavior.
# - The fact that both distributions follow nearly the same trend suggests that other factors (such as artist similarity, genre similarity, or historical voting patterns) are playing a much bigger role.
#
# · Implications for model performance:
#
# - The wide spread of residuals indicates that the model is struggling to capture all the factors influencing voting, since many points awarded deviate significantly from the predictions.
# - The right-skewness and extreme values suggest that external sociopolitical and cultural factors are likely influencing Eurovision voting—factors that are not captured by the variables in the model (distance, GDP, genre, and artist similarity).

# %% [markdown]
# # Linear Regression Country-wise using only distance (mean)

# %% [markdown]
# Fist, we need to obtain a list containing all the participat countries, so we can iterate over them:

# %%
participant_countries = filtered_data["from_country"].unique()
print(participant_countries)
# Out:
# ['al' 'am' 'at' 'az' 'by' 'be' 'ba' 'bg' 'hr' 'cy' 'cz' 'dk' 'ee' 'fi'
#  'fr' 'ge' 'de' 'gr' 'hu' 'is' 'ie' 'il' 'it' 'lv' 'lt' 'mt' 'md' 'me'
#  'nl' 'mk' 'no' 'pl' 'ru' 'sm' 'si' 'es' 'se' 'ch' 'ua' 'gb' 'pt' 'ro']

# %% [markdown]
# Once obtained, we have to set the analysis that is going to be done to every country:

# %%
def analyze_country_data_only_distance(country_code):

    country_info_path = "../data/country_info.csv"
    country_info = pd.read_csv(country_info_path)

    country_row = country_info[country_info["code"].str.lower() == country_code.lower()]    # Map the country code to its corresponding country 
    if country_row.empty:
        print(f"Country {country_code} not found in the country information dataset.")
        return
    country_name = country_row["name"].values[0]

    country_data = aggregated_data[aggregated_data["from_country"] == country_code]
    X_agg = sm.add_constant(country_data["distance_normalized"])
    Y_agg = country_data["tele_points"]

    agg_model = sm.OLS(Y_agg, X_agg).fit()
    agg_summary = agg_model.summary()

    plt.figure(figsize=(8, 5))
    plt.scatter(country_data["distance_normalized"], country_data["tele_points"], alpha=0.5, label="Average points by normalized distance")
    plt.plot(country_data["distance_normalized"], agg_model.predict(X_agg), color="red", label="Regression line")
    plt.title(f"Linear Regression country-wise: Average Tele-points vs. Normalized Distance ({country_name} - {country_code})")
    plt.xlabel("Normalized distance between capitals")
    plt.ylabel("Average tele-points")
    plt.legend()
    plt.grid(True)
    plt.savefig(f"../plots/linear_regression/{country_name}_{country_code}_normalized_tele.png")
    #plt.show()
    plt.close()

    p_value = agg_model.pvalues["distance_normalized"]
    coefficient = agg_model.params["distance_normalized"]
    #print(agg_summary)

    return country_name, p_value, coefficient, agg_model.resid

# %% [markdown]
# We want to separate the countries into two lists: in one of them we will add the countries whose p-value is significant (applying Bonferroni COrrection) and in the other, those that do not, both being ordered from lowest to highest p-value.

# %%
significant_countries = []
non_significant_countries = []
all_residuals = []

for country in participant_countries:
    country_code, p_value, coefficient, residuals = analyze_country_data_only_distance(country)

    all_residuals.extend(residuals)

    if p_value < 0.05 / len(participant_countries):
        significant_countries.append((country_code, p_value, coefficient))
    else:
        non_significant_countries.append((country_code, p_value, coefficient))

significant_countries.sort(key=lambda x: x[1])
non_significant_countries.sort(key=lambda x: x[1])

print(f"\nSignificant countries (p < {0.05 / len(participant_countries)}):")
for country, p_val, coefficient in significant_countries:
    print(f"{country}: p-value = {p_val:.6f} - coefficient = {coefficient:.6f}")

print(f"\nNon-significant countries (p < {0.05 / len(participant_countries)}):")
for country, p_val, coefficient in non_significant_countries:
    print(f"{country}: p-value = {p_val:.6f} - coefficient = {coefficient:.6f}")

plt.figure(figsize=(8, 6))
stats.probplot(all_residuals, dist="norm", plot=plt)
plt.title("Q-Q Plot of All Residuals from Country-wise Models")
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")
plt.grid(True)
plt.savefig("../plots/linear_regression/qqplot_all_countries_only_distance_tele.png")
plt.show()
# Out:
# Significant countries (p < 0.0011904761904761906):
# Estonia: p-value = 0.000002 - coefficient = -2.130697
# Georgia: p-value = 0.000207 - coefficient = -1.509328
# North Macedonia: p-value = 0.001070 - coefficient = -1.562757
#
# Non-significant countries (p < 0.0011904761904761906):
# Latvia: p-value = 0.001271 - coefficient = -1.646466
# Sweden: p-value = 0.001441 - coefficient = -1.339612
# Iceland: p-value = 0.002560 - coefficient = -0.970248
# Finland: p-value = 0.003348 - coefficient = -1.158745
# Denmark: p-value = 0.004479 - coefficient = -1.260117
# Lithuania: p-value = 0.007899 - coefficient = -1.422218
# Norway: p-value = 0.011387 - coefficient = -1.030786
# Croatia: p-value = 0.012385 - coefficient = -1.164080
# Albania: p-value = 0.014059 - coefficient = -1.231326
# Montenegro: p-value = 0.016207 - coefficient = -1.428341
# Cyprus: p-value = 0.022874 - coefficient = -1.075082
# Slovenia: p-value = 0.043297 - coefficient = -1.135118
# Russia: p-value = 0.053438 - coefficient = -1.176115
# Ukraine: p-value = 0.054648 - coefficient = -1.036512
# Netherlands: p-value = 0.074474 - coefficient = -0.553758
# Moldova: p-value = 0.077400 - coefficient = -1.110397
# France: p-value = 0.112279 - coefficient = 0.745822
# Greece: p-value = 0.118175 - coefficient = -0.776677
# Bulgaria: p-value = 0.121545 - coefficient = -0.794575
# Armenia: p-value = 0.123091 - coefficient = -0.628026
# Germany: p-value = 0.124530 - coefficient = -0.678881
# Czechia: p-value = 0.134939 - coefficient = 0.785263
# Azerbaijan: p-value = 0.169789 - coefficient = -0.504392
# Belgium: p-value = 0.170645 - coefficient = -0.535071
# Switzerland: p-value = 0.171156 - coefficient = -0.643940
# Romania: p-value = 0.184883 - coefficient = -0.763599
# Poland: p-value = 0.259060 - coefficient = -0.539325
# Austria: p-value = 0.313504 - coefficient = -0.428838
# Belarus: p-value = 0.351153 - coefficient = -0.568124
# Ireland: p-value = 0.367190 - coefficient = -0.385481
# Malta: p-value = 0.430548 - coefficient = -0.378499
# United Kingdom: p-value = 0.447054 - coefficient = -0.381505
# Portugal: p-value = 0.469098 - coefficient = -0.300608
# Spain: p-value = 0.606771 - coefficient = -0.211799
# Hungary: p-value = 0.663985 - coefficient = 0.276092
# Bosnia and Herzegovina: p-value = 0.685058 - coefficient = -0.397551
# Italy: p-value = 0.758819 - coefficient = 0.189794
# San Marino: p-value = 0.864276 - coefficient = -0.077561
# Israel: p-value = 0.968049 - coefficient = 0.015327

# %% [markdown]
# The residuals do not follow a normal distribution, which can be problematic for the validity of the linear regression results.
#
# The central part of the graph follows the red line, so the residuals in this region approximately follow a normal distribution.
#
# This pattern is characteristic of a distribution with heavier tails than the normal distribution (e.g., a t-Student distribution, skewed data, or heteroscedasticity).

# %% [markdown]
# ### Checking heteroscedascity

# %%
import statsmodels.stats.diagnostic as smd
smd.het_breuschpagan(all_residuals, X_agg)
# Out:
# (0.09626657863851973,
#  0.7563567385203895,
#  0.09615323490666489,
#  0.7565356795424812)

# %%
import matplotlib.pyplot as plt

fitted_values = X_agg @ agg_model.params  # Predicted values
plt.scatter(fitted_values, all_residuals, alpha=0.5)
plt.axhline(0, color="red", linestyle="--")
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs. Fitted Values")
plt.grid(True)
plt.show()

# %% [markdown]
# It does not seems to be heteroscedastic.

# %% [markdown]
# # Linear Regression Country-wise using all (mean)

# %%
def analyze_country_data(country_code):

    country_info_path = "../data/country_info.csv"
    country_info = pd.read_csv(country_info_path)

    country_row = country_info[country_info["code"].str.lower() == country_code.lower()]    # Map the country code to its corresponding country 
    if country_row.empty:
        print(f"Country {country_code} not found in the country information dataset.")
        return
    country_name = country_row["name"].values[0]

    country_data = aggregated_data[aggregated_data["from_country"] == country_code]
    X_full = country_data[["distance_normalized", "GDP_Difference", "dice_genre", "dice_artists", "Catholism_Difference", "Protestant_Difference", "Islam_Difference", "Judaism_Difference"]]
    X_agg = sm.add_constant(X_full)
    Y_agg = country_data["tele_points"]

    agg_model = sm.OLS(Y_agg, X_agg).fit()
    agg_summary = agg_model.summary()
    
    p_value = agg_model.pvalues["distance_normalized"]
    coefficient = agg_model.params["distance_normalized"]
    #print(agg_summary)

    return country_name, p_value, coefficient, agg_model.resid

# %%
significant_countries = []
non_significant_countries = []
all_residuals = []

for country in participant_countries:
    country_code, p_value, coefficient, residuals = analyze_country_data(country)

    all_residuals.extend(residuals)

    if p_value < 0.05 / len(participant_countries):
        significant_countries.append((country_code, p_value, coefficient))
    else:
        non_significant_countries.append((country_code, p_value, coefficient))

significant_countries.sort(key=lambda x: x[1])
non_significant_countries.sort(key=lambda x: x[1])

print(f"\nSignificant countries (p < {0.05 / len(participant_countries)}):")
for country, p_val, coefficient in significant_countries:
    print(f"{country}: p-value = {p_val:.6f} - coefficient = {coefficient:.6f}")

print(f"\nNon-significant countries (p < {0.05 / len(participant_countries)}):")
for country, p_val, coefficient in non_significant_countries:
    print(f"{country}: p-value = {p_val:.6f} - coefficient = {coefficient:.6f}")

plt.figure(figsize=(8, 6))
stats.probplot(all_residuals, dist="norm", plot=plt)
plt.title("Q-Q Plot of All Residuals from Country-wise Models")
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")
plt.grid(True)
plt.savefig("../plots/linear_regression/qqplot_all_countries_tele.png")
plt.show()
# Out:
# Significant countries (p < 0.0011904761904761906):
#
# Non-significant countries (p < 0.0011904761904761906):
# Estonia: p-value = 0.001468 - coefficient = -1.696186
# North Macedonia: p-value = 0.001996 - coefficient = -1.568914
# Latvia: p-value = 0.014191 - coefficient = -1.493537
# Slovenia: p-value = 0.023454 - coefficient = -1.579433
# Georgia: p-value = 0.023920 - coefficient = -1.452458
# Croatia: p-value = 0.032751 - coefficient = -1.050957
# Albania: p-value = 0.038966 - coefficient = -1.137344
# Sweden: p-value = 0.079460 - coefficient = -0.732889
# Montenegro: p-value = 0.103331 - coefficient = -0.879725
# Finland: p-value = 0.139822 - coefficient = -0.641171
# Switzerland: p-value = 0.150801 - coefficient = -0.932090
# Lithuania: p-value = 0.156128 - coefficient = -0.857549
# Armenia: p-value = 0.165248 - coefficient = -0.914259
# Denmark: p-value = 0.168043 - coefficient = -0.574364
# Malta: p-value = 0.201567 - coefficient = -0.811206
# France: p-value = 0.213448 - coefficient = 0.840765
# Moldova: p-value = 0.244679 - coefficient = -0.852037
# Norway: p-value = 0.245918 - coefficient = -0.580478
# Greece: p-value = 0.266482 - coefficient = -0.598216
# Czechia: p-value = 0.276646 - coefficient = 0.681004
# Russia: p-value = 0.288849 - coefficient = -0.841693
# Azerbaijan: p-value = 0.299289 - coefficient = -0.558900
# Romania: p-value = 0.342457 - coefficient = -0.753322
# Portugal: p-value = 0.348046 - coefficient = -0.626818
# Austria: p-value = 0.374562 - coefficient = -0.434667
# Bosnia and Herzegovina: p-value = 0.375369 - coefficient = -1.243278
# Germany: p-value = 0.382635 - coefficient = -0.486853
# Iceland: p-value = 0.397666 - coefficient = -0.354861
# Bulgaria: p-value = 0.446958 - coefficient = -0.442060
# Cyprus: p-value = 0.452293 - coefficient = -0.573306
# Italy: p-value = 0.496514 - coefficient = -0.502014
# Ukraine: p-value = 0.596457 - coefficient = -0.330501
# Ireland: p-value = 0.599404 - coefficient = -0.317240
# Belarus: p-value = 0.681129 - coefficient = 0.265230
# Spain: p-value = 0.721838 - coefficient = -0.208654
# Netherlands: p-value = 0.733144 - coefficient = -0.147930
# San Marino: p-value = 0.770418 - coefficient = 0.146286
# Hungary: p-value = 0.849499 - coefficient = 0.144223
# United Kingdom: p-value = 0.923100 - coefficient = 0.074868
# Israel: p-value = 0.941905 - coefficient = 0.041689
# Belgium: p-value = 0.968075 - coefficient = -0.024704
# Poland: p-value = 0.998902 - coefficient = -0.000661
